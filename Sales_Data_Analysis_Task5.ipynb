# %% [markdown]
# # Sales Data Analysis using Python and Pandas
#
# ## Objective
#
# The objective of this project is to analyze sales data using Python and Pandas.
# The analysis includes data inspection, handling missing values, filtering records,
# grouping sales data, and creating visualizations.
#
# ## Tools Used
#
# - Python
# - Pandas
# - Matplotlib
# - Google Colab
#
# ## Dataset
#
# The dataset contains 100 sales records with the following columns:
#
# - Date
# - Product
# - Category
# - Sales
# - Quantity
# - Region

# %% [markdown]
# ## 1. Import Required Libraries

# %%
import pandas as pd

# %%
from google.colab import files

# %%
uploaded = files.upload()
# Out:
#      <input type="file" id="files-f62079a0-a782-4fba-8af1-dd0859282a7e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-f62079a0-a782-4fba-8af1-dd0859282a7e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ## 2. Load the Dataset

# %%
df = pd.read_csv("sales_data_100_rows.csv")

# %% [markdown]
# ## 3. Basic Data Inspection

# %%
df.head()
# Out:
#          Date     Product     Category  Sales  Quantity Region
# 0  2026-01-01      Tablet  Electronics   1400         4  North
# 1  2026-01-02      Tablet  Electronics   1050         3   West
# 2  2026-01-03     Monitor  Electronics   1100         5   East
# 3  2026-01-04  Smartphone  Electronics   1500         3   East
# 4  2026-01-05       Mouse  Accessories    120         3   West

# %%
df.shape
# Out:
# (100, 6)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 6 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Date      100 non-null    object
#  1   Product   100 non-null    object
#  2   Category  100 non-null    object
#  3   Sales     100 non-null    int64
#  4   Quantity  100 non-null    int64
#  5   Region    100 non-null    object
# dtypes: int64(2), object(4)
# memory usage: 4.8+ KB

# %% [markdown]
# ## 4. Handling Missing Values

# %%
df.isna().sum()
# Out:
# Date        0
# Product     0
# Category    0
# Sales       0
# Quantity    0
# Region      0
# dtype: int64

# %% [markdown]
# ## 5. Filtering Data

# %%
df = df.fillna(0)

# %%
df.isna().sum()
# Out:
# Date        0
# Product     0
# Category    0
# Sales       0
# Quantity    0
# Region      0
# dtype: int64

# %%
df[df["Sales"] > 100]
# Out:
#           Date     Product     Category  Sales  Quantity Region
# 0   2026-01-01      Tablet  Electronics   1400         4  North
# 1   2026-01-02      Tablet  Electronics   1050         3   West
# 2   2026-01-03     Monitor  Electronics   1100         5   East
# 3   2026-01-04  Smartphone  Electronics   1500         3   East
# 4   2026-01-05       Mouse  Accessories    120         3   West
# ..         ...         ...          ...    ...       ...    ...
# 95  2026-04-06      Laptop  Electronics   1500         2   West
# 96  2026-04-07      Laptop  Electronics   2250         3   West
# 97  2026-04-08      Laptop  Electronics    750         1  South
# 98  2026-04-09      Tablet  Electronics    700         2   East
# 99  2026-04-10      Tablet  Electronics   1400         4   West
#
# [97 rows x 6 columns]

# %%
df[df["Category"] == "Elecronics"]
# Out:
# Empty DataFrame
# Columns: [Date, Product, Category, Sales, Quantity, Region]
# Index: []

# %% [markdown]
# ## 6. loc[] and iloc[]

# %%
df.loc[df["Sales"] > 100]
# Out:
#           Date     Product     Category  Sales  Quantity Region
# 0   2026-01-01      Tablet  Electronics   1400         4  North
# 1   2026-01-02      Tablet  Electronics   1050         3   West
# 2   2026-01-03     Monitor  Electronics   1100         5   East
# 3   2026-01-04  Smartphone  Electronics   1500         3   East
# 4   2026-01-05       Mouse  Accessories    120         3   West
# ..         ...         ...          ...    ...       ...    ...
# 95  2026-04-06      Laptop  Electronics   1500         2   West
# 96  2026-04-07      Laptop  Electronics   2250         3   West
# 97  2026-04-08      Laptop  Electronics    750         1  South
# 98  2026-04-09      Tablet  Electronics    700         2   East
# 99  2026-04-10      Tablet  Electronics   1400         4   West
#
# [97 rows x 6 columns]

# %%
df.iloc[0:5]
# Out:
#          Date     Product     Category  Sales  Quantity Region
# 0  2026-01-01      Tablet  Electronics   1400         4  North
# 1  2026-01-02      Tablet  Electronics   1050         3   West
# 2  2026-01-03     Monitor  Electronics   1100         5   East
# 3  2026-01-04  Smartphone  Electronics   1500         3   East
# 4  2026-01-05       Mouse  Accessories    120         3   West

# %% [markdown]
# ## 7. Sales Analysis using groupby()

# %%
category_sales = df.groupby("Category")["Sales"].sum()
category_sales
# Out:
# Category
# Accessories     5965
# Electronics    95590
# Name: Sales, dtype: int64

# %%
region_sales = df.groupby("Region")["Sales"].sum()
region_sales
# Out:
# Region
# East     20740
# North    33735
# South    24255
# West     22825
# Name: Sales, dtype: int64

# %%
df.groupby("Region")

# %%
product_sales = df.groupby("Product")["Sales"].sum()
product_sales
# Out:
# Product
# Headphones     3900
# Keyboard       4725
# Laptop        47250
# Monitor        7040
# Mouse          1240
# Smartphone    15000
# Tablet        22400
# Name: Sales, dtype: int64

# %%
category_sales
# Out:
# Category
# Accessories     5965
# Electronics    95590
# Name: Sales, dtype: int64

# %% [markdown]
# ## 8. Sales Visualization

# %%
import matplotlib.pyplot as plt

# %%
category_sales.plot(kind="bar")

plt.title("Total Sales by Category")
plt.xlabel("Category")
plt.ylabel("Total Sales")

plt.show()

# %%
df["Date"] = pd.to_datetime(df["Date"])

# %%
daily_sales = df.groupby("Date")["Sales"].sum()
daily_sales
# Out:
# Date
# 2026-01-01    1400
# 2026-01-02    1050
# 2026-01-03    1100
# 2026-01-04    1500
# 2026-01-05     120
#               ...
# 2026-04-06    1500
# 2026-04-07    2250
# 2026-04-08     750
# 2026-04-09     700
# 2026-04-10    1400
# Name: Sales, Length: 100, dtype: int64

# %%
daily_sales.plot(kind="line", figsize=(10, 5))

plt.title("Sales Trend Over Time")
plt.xlabel("Date")
plt.ylabel("Total Sales")

plt.xticks(rotation=45)
plt.tight_layout()

plt.show()

# %% [markdown]
# ## 9. Sales Insights

# %%
category_sales.idxmax()
# Out:
# 'Electronics'

# %%
region_sales.idxmax()
# Out:
# 'North'

# %%
product_sales.idxmax()
# Out:
# 'Laptop'

# %%
df["Sales"].sum()
# Out:
# np.int64(101555)

# %%
print("Highest-selling Category:", category_sales.idxmax())
print("Highest-selling Region:", region_sales.idxmax())
print("Highest-selling Product:", product_sales.idxmax())
print("Total Sales:", df["Sales"].sum())
# Out:
# Highest-selling Category: Electronics
# Highest-selling Region: North
# Highest-selling Product: Laptop
# Total Sales: 101555

# %% [markdown]
# ## 10. Conclusion

# %% [markdown]
# The sales data was successfully analyzed using Python and Pandas.
#
# ### Key Insights
#
# - Electronics is the highest-selling category.
# - North is the highest-selling region.
# - Laptop is the highest-selling product.
# - The total sales recorded in the dataset are 10,155.
#
# The analysis also demonstrated data inspection, missing-value handling, filtering, loc[], iloc[], groupby(), and sum(). Bar and line charts were used to visualize the sales data and identify sales patterns.
